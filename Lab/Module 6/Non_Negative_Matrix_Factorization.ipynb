# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Non-Negative Matrix Factorization
#
# Estimated time needed: **45** minutes

# %% [markdown]
# You've been hired by a video streaming platform that specializes in kids content. The company would like to ensure that all content on the platform does not infringe on a copyright written material. The company has created an image database of copyrighted material, not only must you detect the same images you must detect similar images. Your  job is to come up with an image retrieval system to find the most similar image to each image in the provided dataset. Because your model is used for legal purposes it must be interpretable, this means it should be able to determine why the images are similar. As a result, you will use Non-Negative Matrix factorization since the factorized matrices can be interpreted as real images. You will use the [Anime Face Dataset](https://www.kaggle.com/datasets/splcher/animefacedataset?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01) from kaggle.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/fake_cartoon.png" alt="cognitiveclass.ai logo">
#
# <a href="https://www.piratesandprincesses.net/the-story-of-goodtimes-and-their-numerous-disney-knockoffs/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01"> image source</a>

# %% [markdown]
# ## Table of Contents
#
# <ol>
#     <li><a href="#Objectives">Objectives</a></li>
#     <li><a href="#Datasets">Datasets</a></li>
#     <li>
#         <a href="#Setup">Setup</a>
#         <ol>
#             <li><a href="#Installing-Required-Libraries">Installing Required Libraries</a></li>
#             <li><a href="#Importing-Required-Libraries">Importing Required Libraries</a></li>
#             <li><a href="#Defining-Helper-Functions">Defining Helper Functions</a></li>
#         </ol>
#     </li>
#     <li>
#         <a href="#Background">Background</a>
#         <ol>
#                <li><a href="#What's a Non-Negative Matrix Fatorization?">What's a Non-Negative Matrix Fatorization?</a></li>
#         </ol>
#     </li>
#   <li><a href="#Applying Non-Negative Matrix Factorization">Applying Non-Negative Matrix Factorization</a></li>
#   <li><a href="#Image Retrieval System">Image Retrieval System</a></li>
#    <li><a href="#Exercises">Exercises</a>
#        <ol>
#             <li><a href="#Exercise 1">Exercise 1</a></li>
#             <li><a href="#Exercise 2">Exercise 2</a></li>
#             <li><a href="#Exercise 3">Exercise 3</a></li>
#             <li><a href="#Exercise 4">Exercise 4</a></li>
#             <li><a href="#Exercise 5">Exercise 5</a></li>
#         </ol>
#     </li>
#  </ol>
#
#
#
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# - __Understand__ Basics Matrix operations  such as Matrix addition  , Vector Multiplication，and Eigen decomposition
#
# - __Apply__ Apply these Matrix operations using numpy

# %% [markdown]
# ***

# %% [markdown]
# ## Datasets
#
# Download and unzip the **images** dataset:

# %%
import skillsnetwork

# Prepare the dataset by downloading and unzipping the images file
await skillsnetwork.prepare("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/images.tar.gz")
# Out:
# Downloading images.tar.gz:   0%|          | 0/60016218 [00:00<?, ?it/s]
#   0%|          | 0/20006 [00:00<?, ?it/s]
# Saved to '.'

# %%
# Install the skillsnetwork library if it's not already installed
# !pip install skillsnetwork
# Out:
# Requirement already satisfied: skillsnetwork in /usr/local/lib/python3.12/dist-packages (0.21.10)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (7.34.0)
# Requirement already satisfied: ipywidgets<=8.1.3 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (7.7.1)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4 in /usr/local/lib/python3.12/dist-packages (from skillsnetwork) (4.67.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets<=8.1.3->skillsnetwork) (3.0.15)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->skillsnetwork) (4.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->skillsnetwork) (2025.10.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (6.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->skillsnetwork) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->skillsnetwork) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->skillsnetwork) (0.2.14)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.5.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (5.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (2.9.0.post0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.1.6)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.23.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (4.5.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.25.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets<=8.1.3->skillsnetwork) (1.17.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.27.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.14.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.23)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.11.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (7.7.0)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.9.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (4.0.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /usr/local/lib/python3.12/dist-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets<=8.1.3->skillsnetwork) (2.9.0.20251008)

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for managing the data.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for mathematical operations.
# *   [`seaborn`](https://seaborn.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for visualizing the data.
# *   [`matplotlib`](https://matplotlib.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for visualizing the data.
# *   [`sklearn`](https://scikit-learn.org/stable/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML240ENSkillsNetwork34171862-2022-01-01) for machine learning and machine-learning-pipeline related functions.

# %% [markdown]
# ### Installing required libraries

# %% [markdown]
# The following required modules are pre-installed in the Skills Network Labs environment. However, if you run this notebook commands in a different Jupyter environment (e.g. Watson Studio or Ananconda) you will need to install these libraries by removing the `#` sign before `!mamba` in the code cell below.

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented.
# !mamba install -qy pandas==1.3.4 numpy==1.21.4 seaborn==0.9.0 matplotlib==3.5.0 scikit-learn==0.20.1
# Note: If your environment doesn't support "!mamba install", use "!pip install"

# %% [markdown]
# you can use  <a href="https://www.sympy.org/en/index.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01">SymPy </a>this to print matrices

# %%
#!conda install -c anaconda sympy -y

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
import warnings
warnings.simplefilter('ignore')

import logging
import numpy as np
import pandas as pd
from numpy.random import RandomState
import matplotlib.pyplot as plt


from sklearn.decomposition import NMF


from os import listdir,getcwd
from os.path import isfile, join
from PIL import Image, ImageOps
import os

# %% [markdown]
# ### Defining Helper Functions

# %% [markdown]
# Load train and test set:

# %%
# Function to load and preprocess image data
def get_data_matrix(test=False,Length=100,Width=100,mypath="images/"):

    # Get list of files in the specified directory, excluding hidden files
    files = [join(mypath,f) for f in listdir(mypath) if isfile(join(mypath, f)) and f[0] != '.']
    # Remove the .DS_Store file if it exists
    if mypath + '/.DS_Store' in files:
        files.remove(mypath + '/.DS_Store')

    # Split data into training and testing sets based on the 'test' flag
    if test:
        print("test data")
        files=files[9000:10000]

    else:
        print("training data")
        files=files[0:9000]

    print(len(files))
    # Initialize a numpy array to store flattened image data
    X=np.zeros((len(files),Length*Width))
    # Process each image file
    for i,file in enumerate(files):
        # Open and resize the image
        img = Image.open(file).resize((Width, Length))
        # Convert the image to grayscale
        img =  ImageOps.grayscale(img)

        # Convert the image to a numpy array
        I=np.array(img)

        # Flatten the image array and store it in the data matrix
        X[i,:]=I.reshape(1,-1)
    return X

# %% [markdown]
# Plot image vectors:

# %%
# Function to reshape a flattened image vector and display it
def reshape_row(x) :
    plt.imshow(x.reshape(Length,Width),cmap="gray")

# %% [markdown]
# This threshold function outputs an index if the input ```similar_distance``` is grater than or less than ```min_``` and ```max_```.

# %%
# Function to filter dataset and query indices based on similarity distance thresholds
def threshold(similar_distance,max_=0.1,min_=0):
    # Find indices where similar_distance is within the specified range
    dataset_index=np.where(np.logical_and(similar_distance>min_ ,similar_distance<max_))[0]
    query_index=similar_index[np.logical_and(similar_distance>min_ ,similar_distance<max_)]
    return dataset_index,query_index

# %% [markdown]
# Plot dataset images and query images, ```X``` and ```X_q``` are global variables.

# %%
# Function to plot dataset and query images side by side
def plot_data_query(dataset_index,query_index,N):
    # Iterate through the specified number of samples (N)
    for data_sample,query_sample in zip(dataset_index[0:N],query_index[0:N]):

        plt.figure(figsize=(10,4))
        plt.subplot(1,2,1)
        # Reshape and display the dataset image
        reshape_row(X[data_sample])
        plt.title("dataset sample {}".format(data_sample))
        plt.subplot(1,2,2)
        # Reshape and display the query image match
        reshape_row(X_q[query_sample])
        plt.title("query sample match {}".format(query_sample))
        plt.show()

        print("-----------------------------------------------------")

# %% [markdown]
# ## Background

# %% [markdown]
# ### What's a Non-Negative Matrix Factorization?

# %% [markdown]
# In Non-Negative Matrix Factorization (NNMF) sometimes called non-negative matrix approximation, a $N x D$ matrix $\mathbf{X}$, where $N$ is the number of samples and $D$ is the dimension of features, contains all non-negative values. In NNMF we construct a non-negative  approximation of $\mathbf{X}$, $\mathbf{\hat{X}}$ such that $\mathbf{\hat{X}}$ is a product of two non-negative matrices $\mathbf{W}$ and $\mathbf{H}$, i.e:
#
# $$\mathbf{\hat{X}}=\mathbf{WH}$$
#
# where the $r$ rows of $\mathbf{H}$ are called the basis, and we are going to represent the matrix $\mathbf{X}$ in terms of this basis.
#
# Each row of $\mathbf{W}$, ${w}_i$ is called an encoding of the corresponding ${x}_i$ in $\mathbf{X}$, which represents "how much" of each basis in $\mathbf{H}$ is to represent ${x}_i$. ${\hat{x}_i}$ is thus a linear combination of the rows of $\mathbf{H}$.

# %% [markdown]
# ## Applying Non-Negative Matrix Factorization

# %% [markdown]
# **Image retrieval** is used for searching and retrieving images from a large database of digital images. Here we would like to find identical or similar  animated faces  for copyright reasons.

# %% [markdown]
# Consider the matrix $\mathbf{X}$ where each row is a flattened $100\times 100$ image.

# %%
# Set image dimensions
Length,Width=100,100
# Load the training data matrix
X=get_data_matrix(test=False,Length=100,Width=100,mypath="images")
# Print the shape of the training data matrix
X.shape
# Out:
# training data
# 9000
# (9000, 10000)

# %% [markdown]
# We can apply ```sklearn.decomposition.NMF``` to obtain the  non-negative matrices, i.e. matrices with all non-negative elements, $(\mathbf{W}$, $\mathbf{H})$ whose product approximates the non-negative matrix $\mathbf{X}$.
#
# Consider the following parameters when building a simple NMF object:
#
# ```n_components```: int; Number of components, if n_components is not set all features are kept.
#
# ```tolfloat```: default=1e-4; Tolerance of the stopping condition.
#
# ```max_iter```: int, (default=200); Maximum number of iterations before timing out.

# %% [markdown]
# Let's select a number of components or basis, namely $r$, for the matrix representation.

# %%
# Set the number of components for NMF
n_components=10

# %% [markdown]
# Initialize our NMF object and fit it to $\mathbf{X}$:

# %%
# Initialize and fit the NMF model to the training data
nmf_estimator = NMF(n_components=n_components, tol=5e-3,max_iter=2000)
nmf_estimator.fit(X)  # original non- negative dataset
# Out:
# NMF(max_iter=2000, n_components=10, tol=0.005)

# %% [markdown]
# The **.components_** method returns the basis found:

# %%
# Get the basis (components) from the fitted NMF model
H = nmf_estimator.components_

# %% [markdown]
# We can reshape the obtained 10 basis into images, and they appear like faces in the dataset:

# %%
# Plot the basis images
plt.figure(figsize=(25, 8))

for i,h in enumerate(H):
    plt.subplot(2, 5, i+1)
    # Reshape and display each basis image
    reshape_row(h)
    plt.title("basis images {}".format(str(i+1)), fontsize=20)

plt.tight_layout()

# %% [markdown]
# We can obtain the encodings of all the images using the **transform** method of the fitted **nmf_estimator**:

# %%
# Get the encodings (transformed data) of the training data using the fitted NMF model
W = nmf_estimator.transform(X)

# %% [markdown]
# For each of the 9000 images we have an encoding of dimension 10:

# %%
# Print the shape of the encodings matrix
W.shape
# Out:
# (9000, 10)

# %% [markdown]
# The encoding tells you the projection of each image in $\mathbf{X}$ on a particular basis. Here we plot out the encoding magnitude for the $i$th image on each basis.

# %%
# Select the encoding vector for the first image
i=0
w=W[i,:]

# Plot the encoding magnitudes for the first image
plt.bar([n+1 for n in range(len(w))],w)
plt.title("encodings for image {} ".format (i+1))
# Out:
# Text(0.5, 1.0, 'encodings for image 1 ')

# %% [markdown]
# We see that for image 1, the second encoding has the highest magnitude, thus we can plot out the basis associated with this encoding (i.e, the second basis) and see that it's very similar to the image. The 9th encoding has a small magnitude, we see the associated basis looks nothing like the image:

# %%
# Plot the original image, a similar basis, and a dissimilar basis for comparison
plt.figure(figsize=(15,4))

plt.subplot(131)
# Reshape and display the original image
reshape_row(X[i,:])
plt.title("Original image")

plt.subplot(132)
# Reshape and display the second basis (similar)
reshape_row(H[1,:])
plt.title("Similar basis 2")

plt.subplot(133)
# Reshape and display the ninth basis (dissimilar)
reshape_row(H[8,:])
plt.title("Dissimilar basis 9")
# Out:
# Text(0.5, 1.0, 'Dissimilar basis 9')

# %% [markdown]
# We can perform the inverse transform using the method **inverse_transform** to get $\mathbf{\hat{X}}$, the approximation of $\mathbf{X}$:

# %%
# Reconstruct the original data using the inverse transform of the NMF model
Xhat=nmf_estimator.inverse_transform(W)

# %% [markdown]
# Each row of $\mathbf{\hat{X}}$ corresponds to an image. We can reshape the row into an image and plot the approximations:

# %%
# Plot original and approximated images side by side for comparison
plt.figure(figsize=(20,8))

for i in range(1,5):
    plt.subplot(2,4,i)
    # Reshape and display the original image
    reshape_row(X[i])
    plt.title(f"Original image {i}")

    plt.subplot(2,4,i+4)
    # Reshape and display the approximated image
    reshape_row(Xhat[i])
    plt.title(f"Approximated image {i}")

# %% [markdown]
# We can verify that the scikit-learn's **inverse_transform** method essentially performs the following matrix operation:

# %%
# Reconstruct the original data using matrix multiplication of W and H
Xhat_M=W@H

# %% [markdown]
# We see the results are identical quantitatively (for the first 10 grayscale values of first image):

# %%
# Compare the first 10 grayscale values of the first image from the inverse transform and matrix multiplication
Xhat[0,:10], Xhat_M[0,:10]
# Out:
# (array([219.17474533, 215.43605336, 212.54162455, 210.845002  ,
#         207.88942725, 204.12870133, 198.94257094, 193.25113086,
#         187.93655925, 184.90980286]),
#  array([219.17474533, 215.43605336, 212.54162455, 210.845002  ,
#         207.88942725, 204.12870133, 198.94257094, 193.25113086,
#         187.93655925, 184.90980286]))

# %% [markdown]
# and qualitatively or visually for the second to fifth image in the dataset:

# %%
# Plot approximated images from inverse transform and matrix multiplication side by side for visual comparison
plt.figure(figsize=(20,8))

for i in range(1,5):
    plt.subplot(2,4,i)
    # Reshape and display the approximated image from inverse transform
    reshape_row(Xhat[i])
    plt.title(f"Approximated image {i} with sklearn")

    plt.subplot(2,4,i+4)
    # Reshape and display the approximated image from matrix multiplication
    reshape_row(Xhat_M[i])
    plt.title(f"Approximated image {i} with matrix operation")

# %% [markdown]
# We can reconstruct the image by adding one component multiplied by it's encoding at a time. This is shown in the following lines of code, as each successive component is added we see the image looks more and more like it's approximation:

# %%
# Reconstruct the first image by adding components one by one and visualize the process
# initialize an image array with 10000 zeros which will be reshaped as 100x100
image=np.zeros((1,10000))

plt.figure(figsize=(25,8))
for i, (w_, h) in enumerate(zip(w, H)):

    # w is the encoding vector of the first image in X
    # reconstruction of the image is a linear combination of H
    plt.subplot(2,5,i+1)
    image += w_*h
    reshape_row(image)
    plt.title(f"{i+1} components added", fontsize=20)
plt.tight_layout()

# %% [markdown]
# ## Image Retrieval System

# %% [markdown]
# An image retrieval system is a system used for browsing, searching and retrieving images from a large database of digital images. In this section we will create an image retrieval system to find similar cartoon characters for copyright infringement.
#
# We define the query dataset as the set of 1000 images. If these images are similar to the images in our original dataset, they may be considered as copyright infringement. We load the query dateset into```X_q``` where each row corresponds to a flattened $100\times 100$ image:

# %%
# Load the query dataset matrix
X_q=get_data_matrix(test=True,Length=100,Width=100,mypath="images")
# Print the shape of the query data matrix
X_q.shape
# Out:
# test data
# 1000
# (1000, 10000)

# %% [markdown]
# The code in the next cell helps us retain much of the important information of the query images and reduces factors that make similar images appear differently such as noise, rotation and scale. In addition, the code results in a matrix `W_q` that requires less computation for calculating the distance metrics. As such we will use the code to find the similar images.

# %%
# Get the encodings (transformed data) of the query data using the fitted NMF model
W_q=nmf_estimator.transform(X_q)
# Print the shape of the query encodings matrix
W_q.shape
# Out:
# (1000, 10)

# %% [markdown]
# We define  the  distance matrix as a  matrix ```D``` containing the distances, taken pairwise, between the elements of the query dataset and the original dataset.  We will use the cosine similarity that computes the normalized dot product of vectors. That is, for $x$ and $x'$ their cosine similarity  is defined as:
#
# $$1-\frac{x' x^T}{\|x'\| \|x\|}$$

# %% [markdown]
# Consider the following set of codes in which case that we represent as 2D vectors.  The original  dataset is in yellow and the query dataset is in blue. We see that the image $h_2$ is nearest  to  $h_{2q}$, and similarly image $h_3$ is nearest  to  $h_{1q}$.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/NNMF_vectors.png" width="500" alt="https://pxhere.com/en/photo/1536663">

# %% [markdown]
# The resultant distance Matrix is shown below, each row consists of a dataset sample and each column consists of a query dataset sample. Each element of the distance Matrix comprises of the distance between the sample of that particular row and that particular column. We see in this case samples that are close together have the smallest  value. For example, image $h_2$  in the second row is nearest to $h_{2q}$ in the second column.

# %% [markdown]
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-ML0187EN-SkillsNetwork/labs/module%203/images/Sim_Matix.png" width="500" alt="https://pxhere.com/en/photo/1536663">

# %% [markdown]
# We will use the function ```pairwise_distances``` from scikit-learn. This method takes either a vector array or a distance matrix, and returns a distance matrix. If the input is a vector array, the distances are computed.

# %%
# Import the pairwise_distances function from scikit-learn
from sklearn.metrics import pairwise_distances

# %%
# calculates the pairwise distance between the NNMF encoded version of
# the original dataset W and the encoded version of the query dataset W_q
D=pairwise_distances(W,W_q,metric='cosine')

# %% [markdown]
# We see the number of rows corresponds to the number of samples in the original dataset and the number of columns  corresponds to the number of samples in the query dateset.

# %%
# Print the shape of the distance matrix
D.shape
# Out:
# (9000, 1000)

# %% [markdown]
# For each sample in the dataset we find the query sample that has the smallest distance to it, which would be the most similar image. As each image in the original dataset corresponds to a row in the distance matrix, the column index with smallest value corresponds to the index of the closest image in the query dataset.

# %%
# Find the index of the most similar query image for each original image
similar_index=np.argmin(D, axis=1)

# %% [markdown]
# We also find the corresponding distance value

# %%
# Find the minimum distance value for each original image
similar_distance=np.min(D, axis=1)

# %% [markdown]
# We plot out the distance values in a histogram; we see the values range from zero to approximately 0.06.

# %%
plt.hist(similar_distance,bins=100)
plt.title("Distance values")
# Out:
# Text(0.5, 1.0, 'Distance values')

# %% [markdown]
# If we try a maximum threshold of $1.0x10^{-5}$ for the distance value for the first five samples, we get identical images

# %%
# Apply the threshold function to find indices of very similar images (distance < 0.00001)
dataset_index,query_index=threshold(similar_distance,max_=0.00001,min_=0)

# %%
# Print the shapes of the resulting dataset and query index arrays
dataset_index.shape, query_index.shape
# Out:
# ((39,), (39,))

# %%
# Print the first 10 indices of the dataset that have a very similar match
dataset_index[:10]
# Out:
# array([  45,   78,  104,  129,  221,  296, 1171, 1338, 1413, 1495])

# %%
# Print the first 10 indices of the query dataset that are very similar matches
query_index[:10]
# Out:
# array([723, 831, 747, 880, 536, 488, 403, 633, 422, 287])

# %% [markdown]
# If we try a threshold of between $5.0x10^{-3}$ and $1.0x10^{-2}$ instead and plot out the first five samples, it is evident the many of the query images are very different from the original.

# %%
# Apply the threshold function to find indices of less similar images (distance between 0.00001 and 0.005)
dataset_index,query_index=threshold(similar_distance,max_=0.005,min_=0.00001)
# Plot the first 5 pairs of dataset and query images that meet this threshold
plot_data_query(dataset_index,query_index,5)
# Out:
# -----------------------------------------------------
# -----------------------------------------------------
# -----------------------------------------------------
# -----------------------------------------------------
# -----------------------------------------------------

# %% [markdown]
# ## Exercises

# %% [markdown]
# In this exercise, you will apply NMF on the [face images](https://scikit-learn.org/stable/auto_examples/decomposition/plot_faces_decomposition.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01#sphx-glr-auto-examples-decomposition-plot-faces-decomposition-py) from scikit-learn and perform an image retrievel task to find pairs of faces that are similar.

# %%
# Import the fetch_olivetti_faces dataset from scikit-learn
from sklearn.datasets import fetch_olivetti_faces

# Set a random state for reproducibility
rng = RandomState(0)
# Fetch the dataset, shuffle it, and set the random state
data = fetch_olivetti_faces(shuffle=True, random_state=rng)
# Extract the image data
X = data.images
# Out:
# downloading Olivetti faces from https://ndownloader.figshare.com/files/5976027 to /root/scikit_learn_data

# %%
# Define the shape of the images
image_shape = (64, 64)

# Function to plot faces
def plot_faces(title, images, n_col, n_row, cmap=plt.cm.gray):
    # Create a figure and axes for plotting
    fig, axs = plt.subplots(
        nrows = n_row,
        ncols = n_col,
        figsize = (2.0*n_col, 2.3*n_row),
        facecolor='white',
        constrained_layout=True)

    # Adjust layout padding
    fig.set_constrained_layout_pads(w_pad=0.01, h_pad=0.02, hspace=0, wspace=0)
    fig.set_edgecolor("black")
    # Set the title of the figure
    fig.suptitle(title, size=16)
    # Iterate through axes and images to plot each face
    for ax, vec in zip(axs.flat, images):
        # Determine the color map range
        vmax = max(vec.max(), -vec.min())
        # Display the image on the current axis
        im = ax.imshow(
            vec.reshape(image_shape),
            cmap=cmap,
            interpolation="nearest",
            vmin=-vmax,
            vmax=vmax)
        # Turn off axis
        ax.axis('off')

    # Add a colorbar to the figure
    fig.colorbar(im, ax=axs, orientation='horizontal', shrink=0.99,
                aspect=40, pad=0.01)
    # Show the plot
    plt.show()

# %% [markdown]
# We use the **plot_faces** function to plot the first 6 faces in the dataset.

# %%
# Plot the first 6 faces from the dataset
plot_faces("6 Faces from the Original Dataset", X[:6], 3, 2)

# %% [markdown]
# ### Exercise 1
#
# Split the dataset into two such that the first 300 is used as the original dataset **X_r** and the remaining 100 is used as the query dataset **X_q**. Initialize a NMF instance with n_components = 10, and use it to transform **X_r** and **X_q** into encodings.

# %%
# Split the dataset into training and query sets and reshape them to 2D
X_r = X[:300].reshape((300, 64*64))
X_q = X[300:].reshape((100, 64*64))

# Initialize an NMF instance
nmf = NMF(n_components=10, tol=5e-3,max_iter=2000)
# Fit the NMF model to the training data and transform it to get encodings
X_r_W = nmf.fit_transform(X_r)
# Transform the query data using the fitted NMF model to get encodings
X_q_W = nmf.fit_transform(X_q)

# %%
# Initialize an NMF model with 6 components
nmf = NMF(n_components=6, tol=5e-3,max_iter=2000)
# Fit the NMF model to the reshaped dataset
nmf.fit(X.reshape((X.shape[0], -1)))
# Out:
# NMF(max_iter=2000, n_components=6, tol=0.005)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# nmf = NMF(n_components=6, tol=5e-3,max_iter=2000)
# nmf.fit(X)
# ```
#
# </details>

# %% [markdown]
# ### Exercise 2
#
# Calculate the pairwise distances between face encodings from the original and query dataset, store the result in **D**.

# %%
# Import the pairwise_distances function from scikit-learn
from sklearn.metrics import pairwise_distances

# Calculate the pairwise cosine distances between the training and query encodings
D = pairwise_distances(X_r_W, X_q_W, metric='cosine')

# %%
# Get the basis (components) from the fitted NMF model
H = nmf.components_
# Plot the basis images
plot_faces("Basis from dataset", H, 3, 2)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# H = nmf.components_
# plot_faces("Basis from dataset", H, 3, 2)
# ```
#
# </details>

# %% [markdown]
# ### Exercise 3
#
# For all rows in the pairwise distance matrix, output their smallest distances as **similar_distance**, and the index associated with the smallest distances as **similar_index**.

# %%
# Find the index of the most similar query face for each original face
similar_index = np.argmin(D, axis=1)
# Find the minimum distance value for each original face
similar_distance = np.min(D, axis=1)

# %%
# Transform the reshaped dataset using the fitted NMF model to get encodings
W = nmf.transform(X.reshape((X.shape[0], -1)))
# Select the first 6 encodings
w6 = W[:6, :] # picking the first 6 encodings

# Reconstruct the first 6 faces using the inverse transform of the NMF model
X_hat = nmf.inverse_transform(w6)
# Plot the reconstructed faces
plot_faces("6 Reconstructed faces using inverse_transform", X_hat, 3, 2)

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# W = nmf.transform(X)
# w6 = W[:6, :] # picking the first 6 encodings
#
# X_hat = nmf.inverse_transform(w6)
# plot_faces("6 Reconstructed faces using inverse_transform", X_hat, 3, 2)
#
# ```
#
# </details>

# %% [markdown]
# ### Exercise 4
#
# Use the **similar_distance** as input for the **threshold** function. You can specify the min and max threshold for the distances. Return the index of the original dataset and the query dataset that satisfy the specified threshold. Use **plot_data_query** to plot the first 5 pairs of face images that our image retrieval system "views" as similar.

# %%
# Apply the threshold function to find indices of similar faces
o_index, q_index = threshold(similar_distance)

# Set Length and Width for plotting faces
Length=64
Width=64
# Plot the first 5 pairs of similar faces from the dataset and query set
plot_data_query(o_index, q_index, 5)
# Out:
# -----------------------------------------------------
# -----------------------------------------------------
# -----------------------------------------------------
# -----------------------------------------------------
# -----------------------------------------------------

# %%
# Reconstruct the first 6 faces using matrix multiplication of w6 and H
X_hat_M = w6@H
# Plot the reconstructed faces from matrix operations
plot_faces("6 Reconstructed faces using matrix operations", X_hat_M, 3,2)
print("-------------------------------------------------------")
# Plot the reconstructed faces from inverse transform for comparison
plot_faces("6 Reconstructed faces using inverse_transform", X_hat, 3, 2)
# Out:
# -------------------------------------------------------

# %% [markdown]
# <details>
#     <summary>Click here for Solution</summary>
#
# ```python
# X_hat_M = w6@H
# plot_faces("6 Reconstructed faces using matrix operations", X_hat_M, 3,2)
# print("-------------------------------------------------------")
# plot_faces("6 Reconstructed faces using inverse_transform", X_hat, 3, 2)
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Authors

# %% [markdown]
# <a href="https://www.linkedin.com/in/joseph-s-50398b136/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkML0101ENSkillsNetwork20718538-2021-01-01">Joseph Santarcangelo</a> Joseph has a Ph.D. in Electrical Engineering, his research focused on using machine learning, signal processing, and computer vision to determine how videos impact human cognition. Joseph has been working for IBM since he completed his PhD.
#
# [Roxanne Li](https://www.linkedin.com/in/roxanne-li/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork821-2023-01-01) is a Data Science intern at IBM Skills Network, entering level-5 study in the Mathematics & Statistics undergraduate Coop program at McMaster University.

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By  | Change Description             |
# | ----------------- | ------- | ----------- | ------------------------------ |
# | 2022-03-25        | 0.1     | Joseph S.   | Updated all content            |
# | 2022-04-26        | 0.1     | Svitlana K. | Corrected minor grammar errors |
# | 2022-06-06        | 0.1     | Roxanne Li  | Review and edit content        |
